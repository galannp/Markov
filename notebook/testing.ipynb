# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import sys
sys.path.append('../src')

from graph_utils import *

# %%
N = 10
x_star = 2 * np.random.randint(2, size=N) - 1

# %%
r = 0.2
d = 3
a = (2. * d) / (1. + r)
b = a * r

print(f'd = {d}')
print(f'r = {r}')
print(f'a = {a}')
print(f'b = {b}')
# Out:
# d = 3
# r = 0.2
# a = 5.0
# b = 1.0

# %%
A = generate_adjacency(x_star, a, b)

# %%
G = build_graph(A)
draw_graph(G, x_star)
